# %% [markdown]
# # Plotting the Cluster Size vs Cluster Number

# %% [markdown]
# These plots compare the number of molecules in the top 10 largest clusters between the smooth and cliff clusters. 3 plots across 3 different fingerprints.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os
from bb_utils import generate_plots

df=pd.read_csv('clustering_results.csv')
generate_plots.plot_num_molecule(df)

# %% [markdown]
# # Plotting Property std dev vs cluster number

# %% [markdown]
# These plots compare the standard deviation in properties (more specifically log properties) of top 10 largest clusters between the smooth and cliff clusters. 3 plots across 3 different fingerprints.

# %%
generate_plots.plot_prop_std(df)

# %% [markdown]
# # Overall Comparison of two dataframes in finding activity cliffs

# %% [markdown]
# a. In this part, I have compared the improvement in finding ACs, when an offset of 0.3 is used from the usual similarity threshold. Comparison is between the reference (similarity threshold) and new similarity threshold (similarity threshold-offset).
#
# This is a comparison of the recursive method with different offsets.

# %%
df1=pd.read_csv('results/Increasing_Sum_With_Offsets_With_Recur.csv')
df2=pd.read_csv('results/Increasing_Sum_With_Offsets_With_Recur.csv')
generate_plots.plot_overall_comparison(df1, df2, offset1=0.0, offset2=0.3)

# %% [markdown]
# b. Comparison of Non-Recurring method (only 1 iteration of bitbirch and enumerating ACs) across different offsets

# %%
df1=pd.read_csv('results/Increasing_Sum_With_Offsets_No_Recur.csv')
df2=pd.read_csv('results/Increasing_Sum_With_Offsets_No_Recur.csv')
generate_plots.plot_overall_comparison(df1, df2, offset1=0.0, offset2=0.3)

# %% [markdown]
# c. Finally, just to see the difference, comparison between Non Recursive (Offset=0) and Recursive (Offset=0.3)

# %%
df1=pd.read_csv('results/Increasing_Sum_With_Offsets_No_Recur.csv')
df2=pd.read_csv('results/Increasing_Sum_With_Offsets_With_Recur.csv')
generate_plots.plot_overall_comparison(df1, df2, offset1=0.0, offset2=0.3)

# %% [markdown]
# # All comparisons
#
# Compare Recursive and non recursive methods in the presence and absence of offsets

# %%
df1=pd.read_csv('results/Increasing_Sum_With_Offsets_With_Recur.csv')
df2=pd.read_csv('results/Increasing_Sum_With_Offsets_No_Recur.csv')
generate_plots.all_comparisons(df1, df2, offset1=0.0, offset2=0.3)

# %% [markdown]
# # Comparison by Threshold (With and Without offset)

# %% [markdown]
# a. We compare how the accuracy of finding ACs vary across different similarity thresholds.

# %%
df1=pd.read_csv('results/Increasing_Sum_With_Offsets_With_Recur.csv')
df2=pd.read_csv('results/Increasing_Sum_With_Offsets_With_Recur.csv')
generate_plots.plot_comparison_by_threshold(df1, df2, offset1=0.0, offset2=0.3)
# Out:
# c:\Users\akash\OneDrive - University of Florida\AC_New\bb_utils\generate_plots.py:163: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(thresholds, means1, yerr=stds1, fmt='-o', capsize=5, label=f'{fp} {label1} Offset={offset1}', color=color, linewidth=2, marker='s')
# c:\Users\akash\OneDrive - University of Florida\AC_New\bb_utils\generate_plots.py:164: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "--o" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(thresholds, means2, yerr=stds2, fmt='--o', capsize=5, label=f'{fp} {label2} Offset={offset2}', color=color, linewidth=2, marker='o')

# %% [markdown]
# b. We can check the same in the non recursive case.

# %%
df1=pd.read_csv('results/Increasing_Sum_With_Offsets_No_Recur.csv')
df2=pd.read_csv('results/Increasing_Sum_With_Offsets_No_Recur.csv')
generate_plots.plot_comparison_by_threshold(df1, df2, offset1=0.0, offset2=0.3)
# Out:
# c:\Users\akash\OneDrive - University of Florida\AC_New\bb_utils\generate_plots.py:163: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(thresholds, means1, yerr=stds1, fmt='-o', capsize=5, label=f'{fp} {label1} Offset={offset1}', color=color, linewidth=2, marker='s')
# c:\Users\akash\OneDrive - University of Florida\AC_New\bb_utils\generate_plots.py:164: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "--o" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(thresholds, means2, yerr=stds2, fmt='--o', capsize=5, label=f'{fp} {label2} Offset={offset2}', color=color, linewidth=2, marker='o')

# %% [markdown]
# c. Finally, we can check the effect of recursion by comparing the results with non-recursive case

# %%
df1=pd.read_csv('results/Increasing_Sum_With_Offsets_With_Recur.csv')
df2=pd.read_csv('results/Increasing_Sum_With_Offsets_No_Recur.csv')
generate_plots.plot_comparison_by_threshold(df1, df2, offset1=0.0, offset2=0.0)
# Out:
# c:\Users\akash\OneDrive - University of Florida\AC_New\bb_utils\generate_plots.py:163: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(thresholds, means1, yerr=stds1, fmt='-o', capsize=5, label=f'{fp} {label1} Offset={offset1}', color=color, linewidth=2, marker='s')
# c:\Users\akash\OneDrive - University of Florida\AC_New\bb_utils\generate_plots.py:164: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "--o" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(thresholds, means2, yerr=stds2, fmt='--o', capsize=5, label=f'{fp} {label2} Offset={offset2}', color=color, linewidth=2, marker='o')

# %% [markdown]
# d. Comparison of Recursive and Non Recursive at offset=0.3

# %%
df1=pd.read_csv('results/Increasing_Sum_With_Offsets_With_Recur.csv')
df2=pd.read_csv('results/Increasing_Sum_With_Offsets_No_Recur.csv')
generate_plots.plot_comparison_by_threshold(df1, df2, offset1=0.0, offset2=0.0)
# Out:
# c:\Users\akash\OneDrive - University of Florida\AC_New\bb_utils\generate_plots.py:163: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "-o" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(thresholds, means1, yerr=stds1, fmt='-o', capsize=5, label=f'{fp} {label1} Offset={offset1}', color=color, linewidth=2, marker='s')
# c:\Users\akash\OneDrive - University of Florida\AC_New\bb_utils\generate_plots.py:164: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "--o" (-> marker='o'). The keyword argument will take precedence.
#   plt.errorbar(thresholds, means2, yerr=stds2, fmt='--o', capsize=5, label=f'{fp} {label2} Offset={offset2}', color=color, linewidth=2, marker='o')

# %% [markdown]
# # Last but not least, lets get inside clusters!
#
# In this tutorial, we will demonstrate the difference in smooth and cliff clusters. Smooth clusters are devoid of activity cliffs, but cliff clusters most likely do contain some amount of ACs. For this demonstration, we consider the first cluster of CHEMBL4005_Ki dataset. You can change the SMILES file accordinggly but ensure that you change the data and property prefix while loading.

# %%
# Load the input data 

smiles_file='data/CHEMBL4005_Ki.csv'  # Ensure this is consistent with the npy files

from scripts.smooth_ac import FingerprintClusterAnalyzer
import numpy as np

#Intialize the analyzer
analyzer = FingerprintClusterAnalyzer(
        fingerprint_types=['ECFP', 'MACCS', 'RDKIT'],
        thresholds=np.linspace(0.3,0.9,7), # Adjust thresholds as needed
        top=10
    )

# Load data and perform clustering
print("Loading fingerprint data...")
analyzer.load_fingerprint_data(data_prefix='CHEMBL4005_Ki_fp', prop_prefix='CHEMBL4005_Ki_fp') # Change file paths accordingly.

print("\nPerforming clustering...")
analyzer.perform_clustering()

# Save clustering results
analyzer.save_results_to_csv(filename='results/clustering_results_CHEMBL4005_Ki.csv')

# Compare fingerprint types at a specific threshold
print("\n" + "="*80)
print("EXAMPLE 2: Fingerprint Type Comparison")
print("="*80)
analyzer.compare_fingerprint_types(0.9, 1, smiles_file, max_molecules=20) # Visualizes and saves the first (or most populated cluster) across all fingerprint types at 0.9 threshold.
# Out:
# Loading fingerprint data...
# Loaded ECFP: 960 molecules
# Loaded MACCS: 960 molecules
# Loaded RDKIT: 960 molecules
#
# Performing clustering...
#
# Processing ECFP fingerprints...
#   Threshold: 0.3
#     Cliff clusters: 17 (first cluster size: 321)
#     Smooth clusters: 296 (first cluster size: 20)
#   Threshold: 0.4
#     Cliff clusters: 29 (first cluster size: 248)
#     Smooth clusters: 284 (first cluster size: 23)
#   Threshold: 0.5
#     Cliff clusters: 61 (first cluster size: 115)
#     Smooth clusters: 287 (first cluster size: 23)
#   Threshold: 0.6000000000000001
#     Cliff clusters: 137 (first cluster size: 67)
#     Smooth clusters: 325 (first cluster size: 18)
#   Threshold: 0.7000000000000001
#     Cliff clusters: 353 (first cluster size: 26)
#     Smooth clusters: 454 (first cluster size: 15)
#   Threshold: 0.8
#     Cliff clusters: 693 (first cluster size: 8)
#     Smooth clusters: 718 (first cluster size: 9)
#   Threshold: 0.9
#     Cliff clusters: 942 (first cluster size: 4)
#     Smooth clusters: 944 (first cluster size: 4)
#
# Processing MACCS fingerprints...
#   Threshold: 0.3
#     Cliff clusters: 1 (first cluster size: 960)
#     Smooth clusters: 307 (first cluster size: 33)
#   Threshold: 0.4
#     Cliff clusters: 2 (first cluster size: 595)
#     Smooth clusters: 307 (first cluster size: 33)
#   Threshold: 0.5
#     Cliff clusters: 4 (first cluster size: 488)
#     Smooth clusters: 307 (first cluster size: 33)
#   Threshold: 0.6000000000000001
#     Cliff clusters: 13 (first cluster size: 175)
#     Smooth clusters: 307 (first cluster size: 33)
#   Threshold: 0.7000000000000001
#     Cliff clusters: 27 (first cluster size: 140)
#     Smooth clusters: 302 (first cluster size: 25)
#   Threshold: 0.8
#     Cliff clusters: 97 (first cluster size: 92)
#     Smooth clusters: 334 (first cluster size: 18)
#   Threshold: 0.9
#     Cliff clusters: 317 (first cluster size: 35)
#     Smooth clusters: 455 (first cluster size: 14)
#
# Processing RDKIT fingerprints...
#   Threshold: 0.3
#     Cliff clusters: 1 (first cluster size: 960)
#     Smooth clusters: 280 (first cluster size: 24)
#   Threshold: 0.4
#     Cliff clusters: 2 (first cluster size: 959)
#     Smooth clusters: 279 (first cluster size: 24)
#   Threshold: 0.5
#     Cliff clusters: 8 (first cluster size: 319)
#     Smooth clusters: 281 (first cluster size: 24)
#   Threshold: 0.6000000000000001
#     Cliff clusters: 25 (first cluster size: 202)
#     Smooth clusters: 289 (first cluster size: 26)
#   Threshold: 0.7000000000000001
#     Cliff clusters: 45 (first cluster size: 150)
#     Smooth clusters: 294 (first cluster size: 26)
#   Threshold: 0.8
#     Cliff clusters: 136 (first cluster size: 87)
#     Smooth clusters: 333 (first cluster size: 26)
#   Threshold: 0.9
#     Cliff clusters: 397 (first cluster size: 23)
#     Smooth clusters: 479 (first cluster size: 19)
#
# Results saved to results/clustering_results_CHEMBL4005_Ki.csv
#
# ================================================================================
# EXAMPLE 2: Fingerprint Type Comparison
# ================================================================================
#
# ================================================================================
# FINGERPRINT COMPARISON - Threshold: 0.9, Cluster: 1
# ================================================================================
#
# Processing ECFP...
#
# ================================================================================
# VISUALIZING: ECFP Fingerprint, Threshold: 0.9, Cluster: 1
# ================================================================================
# Loaded 960 molecules from data/CHEMBL4005_Ki.csv
# Columns available: ['smiles', 'exp_mean [nM]', 'y', 'cliff_mol', 'split']
#
# Cluster 1 Information:
#   Cliff cluster size: 3
#   Smooth cluster size: 3
#
# Creating cliff cluster visualization (SVG)...
# Saved SVG image: molecules/cliff_cluster_ECFP_0.9_1.svg
#
# Creating smooth cluster visualization (SVG)...
# Saved SVG image: molecules/smooth_cluster_ECFP_0.9_1.svg
#
# ============================================================
# CLUSTER COMPARISON - ECFP (Threshold: 0.9, Cluster: 1)
# ============================================================
#
# Cliff Cluster Statistics:
#   Valid molecules: 3
#   Invalid SMILES: 0
#   Activity range: 1.27 - 5.51 nM
#   Activity mean: 3.05 ± 1.80 nM
#
# Smooth Cluster Statistics:
#   Valid molecules: 3
#   Invalid SMILES: 0
#   Activity range: 1.27 - 5.51 nM
#   Activity mean: 3.05 ± 1.80 nM
#
# Activity Cliff Analysis:
#   Cliff cluster std: 1.80 nM
#   Smooth cluster std: 1.80 nM
#   Cliff/Smooth std ratio: 1.00
#
# Processing MACCS...
#
# ================================================================================
# VISUALIZING: MACCS Fingerprint, Threshold: 0.9, Cluster: 1
# ================================================================================
# Loaded 960 molecules from data/CHEMBL4005_Ki.csv
# Columns available: ['smiles', 'exp_mean [nM]', 'y', 'cliff_mol', 'split']
#
# Cluster 1 Information:
#   Cliff cluster size: 32
#   Smooth cluster size: 12
#
# Creating cliff cluster visualization (SVG)...
# Saved SVG image: molecules/cliff_cluster_MACCS_0.9_1.svg
#
# Creating smooth cluster visualization (SVG)...
# Saved SVG image: molecules/smooth_cluster_MACCS_0.9_1.svg
#
# ============================================================
# CLUSTER COMPARISON - MACCS (Threshold: 0.9, Cluster: 1)
# ============================================================
#
# Cliff Cluster Statistics:
#   Valid molecules: 20
#   Invalid SMILES: 0
#   Activity range: 3.33 - 3779.00 nM
#   Activity mean: 440.21 ± 1020.28 nM
#
# Smooth Cluster Statistics:
#   Valid molecules: 12
#   Invalid SMILES: 0
#   Activity range: 2.68 - 20.30 nM
#   Activity mean: 7.53 ± 6.15 nM
#
# Activity Cliff Analysis:
#   Cliff cluster std: 1020.28 nM
#   Smooth cluster std: 6.15 nM
#   Cliff/Smooth std ratio: 165.80
#
# Processing RDKIT...
#
# ================================================================================
# VISUALIZING: RDKIT Fingerprint, Threshold: 0.9, Cluster: 1
# ================================================================================
# Loaded 960 molecules from data/CHEMBL4005_Ki.csv
# Columns available: ['smiles', 'exp_mean [nM]', 'y', 'cliff_mol', 'split']
#
# Cluster 1 Information:
#   Cliff cluster size: 23
#   Smooth cluster size: 17
#
# Creating cliff cluster visualization (SVG)...
# Saved SVG image: molecules/cliff_cluster_RDKIT_0.9_1.svg
#
# Creating smooth cluster visualization (SVG)...
# Saved SVG image: molecules/smooth_cluster_RDKIT_0.9_1.svg
#
# ============================================================
# CLUSTER COMPARISON - RDKIT (Threshold: 0.9, Cluster: 1)
# ============================================================
#
# Cliff Cluster Statistics:
#   Valid molecules: 20
#   Invalid SMILES: 0
#   Activity range: 3.20 - 437.10 nM
#   Activity mean: 53.07 ± 100.78 nM
#
# Smooth Cluster Statistics:
#   Valid molecules: 17
#   Invalid SMILES: 0
#   Activity range: 1.06 - 5.92 nM
#   Activity mean: 2.63 ± 1.34 nM
#
# Activity Cliff Analysis:
#   Cliff cluster std: 100.78 nM
#   Smooth cluster std: 1.34 nM
#   Cliff/Smooth std ratio: 75.35
#
# ================================================================================
# FINGERPRINT COMPARISON SUMMARY
# ================================================================================
#
# ECFP Fingerprint:
#   Cliff: 3 molecules, std: 1.80 nM
#   Smooth: 3 molecules, std: 1.80 nM
#
# MACCS Fingerprint:
#   Cliff: 20 molecules, std: 1020.28 nM
#   Smooth: 12 molecules, std: 6.15 nM
#
# RDKIT Fingerprint:
#   Cliff: 20 molecules, std: 100.78 nM
#   Smooth: 17 molecules, std: 1.34 nM
# {'ECFP': {'cliff_results': {'molecules': [<rdkit.Chem.rdchem.Mol at 0x1eda1116a40>,
#     <rdkit.Chem.rdchem.Mol at 0x1eda11169d0>,
#     <rdkit.Chem.rdchem.Mol at 0x1eda1116960>],
#    'properties': [5.51, 2.36, 1.27],
#    'smiles': ['Cc1c(N2CCCCC2=O)nc2cc(F)cc(F)c2c1N1CC2(CCOCC2)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(N2CCCC2=O)nc2cc(F)cc(F)c2c1N1CC2(CCOCC2)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(N2CCC2=O)nc2cc(F)cc(F)c2c1N1CC2(CCOCC2)c2ncc(N3CCOCC3)cc21'],
#    'indices': [473, 480, 520],
#    'valid_count': 3,
#    'invalid_count': 0},
#   'smooth_results': {'molecules': [<rdkit.Chem.rdchem.Mol at 0x1eda1116ab0>,
#     <rdkit.Chem.rdchem.Mol at 0x1eda1116b20>,
#     <rdkit.Chem.rdchem.Mol at 0x1eda1116b90>],
#    'properties': [5.51, 2.36, 1.27],
#    'smiles': ['Cc1c(N2CCCCC2=O)nc2cc(F)cc(F)c2c1N1CC2(CCOCC2)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(N2CCCC2=O)nc2cc(F)cc(F)c2c1N1CC2(CCOCC2)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(N2CCC2=O)nc2cc(F)cc(F)c2c1N1CC2(CCOCC2)c2ncc(N3CCOCC3)cc21'],
#    'indices': [473, 480, 520],
#    'valid_count': 3,
#    'invalid_count': 0},
#   'fingerprint_type': 'ECFP',
#   'threshold': 0.9,
#   'cluster_index': 1},
#  'MACCS': {'cliff_results': {'molecules': [<rdkit.Chem.rdchem.Mol at 0x1ed96e9db60>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9dbd0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9dc40>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9dcb0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9dd20>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9dd90>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9de00>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9de70>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9dee0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9df50>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9dfc0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e030>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e0a0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e110>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e180>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e1f0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e260>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e2d0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e340>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e3b0>],
#    'properties': [30.17,
#     155.90000000000006,
#     18.239999999999995,
#     26.81,
#     154.12999999999997,
#     93.68,
#     233.97000000000008,
#     47.5,
#     5.868000000000001,
#     14.52,
#     4.071,
#     55.84,
#     15.64,
#     155.30000000000004,
#     21.090000000000003,
#     3.3270000000000004,
#     20.300000000000004,
#     3078.5000000000014,
#     3779.000000000001,
#     890.4000000000002],
#    'smiles': ['Cc1c(-c2ccccn2)nc2cc(F)ccc2c1N1CC(C)(C)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2cccc(F)c2c1N1CC(C)(C)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2cc(F)ccc2c1N1CC2(CCOCC2)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2cccnc2)nc2cc(F)ccc2c1N1CC(C)(C)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2cccc(C#N)c2)nc2cc(F)ccc2c1N1CC(C)(C)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2c(F)cccc2c1N1CC(C)(C)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccncc2)nc2cc(F)ccc2c1N1CC2(CCOCC2)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2cccnc2)nc2cc(F)ccc2c1N1CC2(CCOCC2)c2ccc(N3CCOCC3)cc21',
#     'CC(C)c1c(-c2ccccn2)nc2cc(F)ccc2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1ncccc1-c1nc2cc(F)ccc2c(N2CC3(CCOCC3)c3ccc(N4CCOCC4)cc32)c1C',
#     'Cc1ncccc1-c1nc2cc(F)ccc2c(N2CC(C)(C)c3ncc(N4CCOCC4)cc32)c1C',
#     'COCCN(C)c1cnc2c(c1)N(c1c(C)c(-c3ccccn3)nc3cc(F)ccc13)CC2(C)C',
#     'Cc1cc(C)cc(-c2nc3cc(F)ccc3c(N3CC(C)(C)c4ncc(N5CCOCC5)cc43)c2C)c1',
#     'Cc1c(-c2cccc(=O)[nH]2)nc2cc(F)ccc2c1N1CC2(CCOCC2)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2cc(F)cc(F)c2c1N1CC2(CCOCC2)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2cccc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(-c2cc(F)ccc2F)nc2cc(F)ccc2c1N1CC(C)(C)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2cc(C(F)(F)F)cc(C(F)(F)F)c2)nc2cc(F)ccc2c1N1CC(C)(C)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2cc(C(F)(F)F)cc(C(F)(F)F)c2)nc2cccc(F)c2c1N1CC(C)(C)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccc2F)nc2cccc(Cl)c2c1N1CC(C)(C)c2ccc(N3CCOCC3)cc21'],
#    'indices': [371,
#     372,
#     373,
#     374,
#     375,
#     376,
#     377,
#     378,
#     379,
#     380,
#     381,
#     382,
#     386,
#     392,
#     397,
#     398,
#     399,
#     400,
#     401,
#     402],
#    'valid_count': 20,
#    'invalid_count': 0},
#   'smooth_results': {'molecules': [<rdkit.Chem.rdchem.Mol at 0x1ed96e9e490>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e420>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e500>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e570>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e5e0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e650>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e6c0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e730>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e7a0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e810>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e880>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96e9e8f0>],
#    'properties': [5.868000000000001,
#     4.071,
#     15.64,
#     3.3270000000000004,
#     20.300000000000004,
#     4.071999999999999,
#     3.2000000000000006,
#     2.9,
#     2.874,
#     8.121,
#     2.676,
#     17.300000000000004],
#    'smiles': ['CC(C)c1c(-c2ccccn2)nc2cc(F)ccc2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1ncccc1-c1nc2cc(F)ccc2c(N2CC(C)(C)c3ncc(N4CCOCC4)cc32)c1C',
#     'Cc1cc(C)cc(-c2nc3cc(F)ccc3c(N3CC(C)(C)c4ncc(N5CCOCC5)cc43)c2C)c1',
#     'Cc1c(-c2ccccn2)nc2cccc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(-c2cc(F)ccc2F)nc2cc(F)ccc2c1N1CC(C)(C)c2ccc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2c(C)ccc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(Cc2ccccc2)nc2cc(F)cc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'C=C(c1ccccc1)c1nc2cc(F)cc(F)c2c(N2CC(C)(C)c3ncc(N4CCOCC4)cc32)c1C',
#     'Cc1c(Cc2cccc(F)c2)nc2cc(F)cc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(CCc2ccccc2)nc2cc(F)cc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(Cc2cccc(C#N)c2)nc2cc(F)cc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(Cc2cccc(C(F)(F)F)c2)nc2cc(F)cc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21'],
#    'indices': [379, 381, 386, 398, 399, 403, 449, 450, 454, 455, 456, 466],
#    'valid_count': 12,
#    'invalid_count': 0},
#   'fingerprint_type': 'MACCS',
#   'threshold': 0.9,
#   'cluster_index': 1},
#  'RDKIT': {'cliff_results': {'molecules': [<rdkit.Chem.rdchem.Mol at 0x1ed96ee4f20>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4f90>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4eb0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4e40>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4dd0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4d60>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4cf0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4c80>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4c10>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4ba0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4b30>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4ac0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4a50>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee49e0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4970>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4900>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4890>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4820>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee47b0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4740>],
#    'properties': [5.868000000000001,
#     55.84,
#     14.739999999999998,
#     3.3270000000000004,
#     4.071999999999999,
#     437.1000000000002,
#     3.2000000000000006,
#     4.170000000000001,
#     18.399999999999995,
#     8.82,
#     9.44,
#     6.48,
#     5.19,
#     65.9,
#     12.500000000000002,
#     22.6,
#     41.6,
#     219.00000000000009,
#     29.0,
#     94.1],
#    'smiles': ['CC(C)c1c(-c2ccccn2)nc2cc(F)ccc2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'COCCN(C)c1cnc2c(c1)N(c1c(C)c(-c3ccccn3)nc3cc(F)ccc13)CC2(C)C',
#     'Cc1c(-c2cccc(=O)[nH]2)nc2cc(F)ccc2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2cccc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2c(C)ccc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'CC1(C)CN(c2c(C#N)c(-c3ccccn3)nc3cc(F)ccc23)c2cc(N3CCOCC3)cnc21',
#     'Cc1c(Cc2ccccc2)nc2cc(F)cc(F)c2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1ccnc(-c2nc3cc(F)ccc3c(N3CC(C)(C)c4ncc(N5CCOCC5)cc43)c2C)c1',
#     'Cc1ccnc(-c2nc3cc(F)cc(F)c3c(N3CC(C)(C)c4ncc(N5CCOCC5)cc43)c2C)c1',
#     'Cc1ccnc(-c2nc3cc(F)cc(F)c3c(N3CC4(CCOCC4)c4ncc(N5CCOCC5)cc43)c2C)c1',
#     'Cc1c(-c2ccccn2)nc2cc(F)cc(F)c2c1N1CC2(CCOCC2)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2cccc(F)c2c1N1CC2(CCOCC2)c2ncc(N3CCOCC3)cc21',
#     'Cc1ccnc(-c2nc3cc(F)ccc3c(N3CC4(CCOCC4)c4ncc(N5CCOCC5)cc43)c2C)c1',
#     'Cc1c(-c2ccccn2)nc2ncccc2c1N1CC2(CCOCC2)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2ncccc2c1N1CC(C)(C)c2ncc(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2cc(F)ccc2c1N1CC2(CCOCC2)c2nc(Br)c(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2cc(F)ccc2c1N1CC2(CCOCC2)c2nc(C#N)c(N3CCOCC3)cc21',
#     'Cc1c(-c2ccccn2)nc2cc(F)ccc2c1N1CC2(CCOCC2)c2nc(N)c(N3CCOCC3)cc21',
#     'C=Cc1nc2c(cc1N1CCOCC1)N(c1c(C)c(-c3ccccn3)nc3cc(F)ccc13)CC21CCOCC1',
#     'Cc1c(-c2ccccn2)nc2cc(F)ccc2c1N1CC2(CCOCC2)c2nc(Cl)c(N3CCOCC3)cc21'],
#    'indices': [379,
#     382,
#     394,
#     398,
#     403,
#     404,
#     449,
#     463,
#     467,
#     472,
#     474,
#     475,
#     484,
#     491,
#     494,
#     510,
#     511,
#     512,
#     513,
#     514],
#    'valid_count': 20,
#    'invalid_count': 0},
#   'smooth_results': {'molecules': [<rdkit.Chem.rdchem.Mol at 0x1ed96ee46d0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4660>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee45f0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4580>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4510>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee44a0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4430>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee43c0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4350>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee42e0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4270>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4200>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4190>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4120>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee40b0>,
#     <rdkit.Chem.rdchem.Mol at 0x1ed96ee4040>,
#     <rdkit.Chem.rdchem.Mol at 0x1eda1590040>],
#    'properties': [2.43,
#     3.19,
#     1.855287569573284,
#     1.2406947890818858,
#     1.96,
#     1.06,
#     2.55,
#     1.38,
#     2.89,
#     5.92,
#     1.7605633802816905,
#     2.1,
#     3.919999999999999,
#     1.084598698481562,
#     2.59,
#     4.970000000000001,
#     3.89],
#    'smiles': ['O=c1[nH]c2cnc3ccc(-c4cnc5ccccc5c4)nc3c2n1C1CCNCC1',
#     'CCN1CCC(n2c(=O)n(C)c3cnc4ccc(-c5cnc6ccccc6c5)nc4c32)CC1',
#     'CCC(=O)N1CCC(n2c(=O)n(C)c3cnc4ccc(-c5cnc6ccccc6c5)nc4c32)CC1',
#     'COC(=O)N1CCC(n2c(=O)n(C)c3cnc4ccc(-c5cnc6ccccc6c5)nc4c32)CC1',
#     'CNC(=O)N1CCC(n2c(=O)n(C)c3cnc4ccc(-c5cnc6ccccc6c5)nc4c32)CC1',
#     'CC(C)C(=O)N1CCC(n2c(=O)n(C)c3cnc4ccc(-c5cnc6ccccc6c5)nc4c32)CC1',
#     'CN(C)CC(=O)N1CCC(n2c(=O)n(C)c3cnc4ccc(-c5cnc6ccccc6c5)nc4c32)CC1',
#     'CCOC(=O)N1CCC(n2c(=O)n(C)c3cnc4ccc(-c5cnc6ccccc6c5)nc4c32)CC1',
#     'CC(C)OC(=O)N1CCC(n2c(=O)n(C)c3cnc4ccc(-c5cnc6ccccc6c5)nc4c32)CC1',
#     'CN1CCC(n2c(=O)n(C)c3cnc4ccc(-c5cnc6ccccc6c5)nc4c32)CC1',
#     'Cn1c(=O)n(C2CCN(C(=O)C(C)(C)O)CC2)c2c3nc(-c4cnc5ccccc5c4)ccc3ncc21',
#     'CN(C)CC(=O)N1CCC(n2c(=O)n(C)c3cnc4ccc(-c5ccc(N(C)C)nc5)nc4c32)CC1',
#     'Cn1c(=O)n(C2CCN(C(=O)C(C)(C)N)CC2)c2c3nc(-c4cnc5ccccc5c4)ccc3ncc21',
#     'COCC(=O)N1CCC(n2c(=O)n(C)c3cnc4ccc(-c5ccc(C)nc5)nc4c32)CC1',
#     'COc1ncc(-c2ccc3ncc4c(c3n2)n(C2CCN(C(=O)[C@H](C)O)CC2)c(=O)n4C)cn1',
#     'COCC(=O)N1CCC(n2c(=O)n(C)c3cnc4ccc(-c5cnc(OC)nc5)nc4c32)CC1',
#     'Cc1ccc(-c2ccc3ncc4c(c3n2)n(C2CCN(C(=O)C(C)(C)O)CC2)c(=O)n4C)cn1'],
#    'indices': [786,
#     787,
#     788,
#     789,
#     790,
#     791,
#     792,
#     793,
#     794,
#     795,
#     808,
#     809,
#     810,
#     817,
#     818,
#     821,
#     822],
#    'valid_count': 17,
#    'invalid_count': 0},
#   'fingerprint_type': 'RDKIT',
#   'threshold': 0.9,
#   'cluster_index': 1}}

# %% [markdown]
# # Specific cluster
#
# If you want to visualize a specific cluster from a specific fingerprint at a specific threshold, the recipe is simple...

# %%
smiles_file='data/CHEMBL4005_Ki.csv'

from scripts.smooth_ac import FingerprintClusterAnalyzer
import numpy as np
#Intialize the analyzer
analyzer = FingerprintClusterAnalyzer(
        fingerprint_types=['ECFP', 'MACCS', 'RDKIT'],
        thresholds=np.linspace(0.3,0.9,7), # Adjust thresholds as needed
        top=10
    )

# Load data and perform clustering
print("Loading fingerprint data...")
analyzer.load_fingerprint_data(data_prefix='CHEMBL4005_Ki_fp', prop_prefix='CHEMBL4005_Ki_fp') # Change file paths accordingly.

print("\nPerforming clustering...")
analyzer.perform_clustering()

# Save clustering results
analyzer.save_results_to_csv(filename='results/clustering_results_CHEMBL4005_Ki.csv')

# Compare fingerprint types at a specific threshold
print("\n" + "="*80)
print("EXAMPLE 2: Fingerprint Type Comparison")
print("="*80)
analyzer.visualize_molecules('MACCS', 0.9, 10, smiles_file, max_molecules=20)
# Out:
# Loading fingerprint data...
# Loaded ECFP: 960 molecules
# Loaded MACCS: 960 molecules
# Loaded RDKIT: 960 molecules
#
# Performing clustering...
#
# Processing ECFP fingerprints...
#   Threshold: 0.3
#     Cliff clusters: 17 (first cluster size: 321)
#     Smooth clusters: 296 (first cluster size: 20)
#   Threshold: 0.4
#     Cliff clusters: 29 (first cluster size: 248)
#     Smooth clusters: 284 (first cluster size: 23)
#   Threshold: 0.5
#     Cliff clusters: 61 (first cluster size: 115)
#     Smooth clusters: 287 (first cluster size: 23)
#   Threshold: 0.6000000000000001
#     Cliff clusters: 137 (first cluster size: 67)
#     Smooth clusters: 325 (first cluster size: 18)
#   Threshold: 0.7000000000000001
#     Cliff clusters: 353 (first cluster size: 26)
#     Smooth clusters: 454 (first cluster size: 15)
#   Threshold: 0.8
#     Cliff clusters: 693 (first cluster size: 8)
#     Smooth clusters: 718 (first cluster size: 9)
#   Threshold: 0.9
#     Cliff clusters: 942 (first cluster size: 4)
#     Smooth clusters: 944 (first cluster size: 4)
#
# Processing MACCS fingerprints...
#   Threshold: 0.3
#     Cliff clusters: 1 (first cluster size: 960)
#     Smooth clusters: 307 (first cluster size: 33)
#   Threshold: 0.4
#     Cliff clusters: 2 (first cluster size: 595)
#     Smooth clusters: 307 (first cluster size: 33)
#   Threshold: 0.5
#     Cliff clusters: 4 (first cluster size: 488)
#     Smooth clusters: 307 (first cluster size: 33)
#   Threshold: 0.6000000000000001
#     Cliff clusters: 13 (first cluster size: 175)
#     Smooth clusters: 307 (first cluster size: 33)
#   Threshold: 0.7000000000000001
#     Cliff clusters: 27 (first cluster size: 140)
#     Smooth clusters: 302 (first cluster size: 25)
#   Threshold: 0.8
#     Cliff clusters: 97 (first cluster size: 92)
#     Smooth clusters: 334 (first cluster size: 18)
#   Threshold: 0.9
#     Cliff clusters: 317 (first cluster size: 35)
#     Smooth clusters: 455 (first cluster size: 14)
#
# Processing RDKIT fingerprints...
#   Threshold: 0.3
#     Cliff clusters: 1 (first cluster size: 960)
#     Smooth clusters: 280 (first cluster size: 24)
#   Threshold: 0.4
#     Cliff clusters: 2 (first cluster size: 959)
#     Smooth clusters: 279 (first cluster size: 24)
#   Threshold: 0.5
#     Cliff clusters: 8 (first cluster size: 319)
#     Smooth clusters: 281 (first cluster size: 24)
#   Threshold: 0.6000000000000001
#     Cliff clusters: 25 (first cluster size: 202)
#     Smooth clusters: 289 (first cluster size: 26)
#   Threshold: 0.7000000000000001
#     Cliff clusters: 45 (first cluster size: 150)
#     Smooth clusters: 294 (first cluster size: 26)
#   Threshold: 0.8
#     Cliff clusters: 136 (first cluster size: 87)
#     Smooth clusters: 333 (first cluster size: 26)
#   Threshold: 0.9
#     Cliff clusters: 397 (first cluster size: 23)
#     Smooth clusters: 479 (first cluster size: 19)
#
# Results saved to results/clustering_results_CHEMBL4005_Ki.csv
#
# ================================================================================
# EXAMPLE 2: Fingerprint Type Comparison
# ================================================================================
#
# ================================================================================
# VISUALIZING: MACCS Fingerprint, Threshold: 0.9, Cluster: 10
# ================================================================================
# Loaded 960 molecules from data/CHEMBL4005_Ki.csv
# Columns available: ['smiles', 'exp_mean [nM]', 'y', 'cliff_mol', 'split']
#
# Cluster 10 Information:
#   Cliff cluster size: 11
#   Smooth cluster size: 8
#
# Creating cliff cluster visualization (SVG)...
# Saved SVG image: molecules/cliff_cluster_MACCS_0.9_10.svg
#
# Creating smooth cluster visualization (SVG)...
# Saved SVG image: molecules/smooth_cluster_MACCS_0.9_10.svg
#
# ============================================================
# CLUSTER COMPARISON - MACCS (Threshold: 0.9, Cluster: 10)
# ============================================================
#
# Cliff Cluster Statistics:
#   Valid molecules: 11
#   Invalid SMILES: 0
#   Activity range: 4.00 - 377.00 nM
#   Activity mean: 87.36 ± 108.31 nM
#
# Smooth Cluster Statistics:
#   Valid molecules: 8
#   Invalid SMILES: 0
#   Activity range: 4.00 - 33.00 nM
#   Activity mean: 15.50 ± 8.99 nM
#
# Activity Cliff Analysis:
#   Cliff cluster std: 108.31 nM
#   Smooth cluster std: 8.99 nM
#   Cliff/Smooth std ratio: 12.05
# {'cliff_results': {'molecules': [<rdkit.Chem.rdchem.Mol at 0x1eda1590b30>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1590ba0>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1590c10>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1590c80>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1590cf0>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1590d60>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1590dd0>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1590e40>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1590eb0>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1590f20>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1590f90>],
#   'properties': [4.0,
#    45.00000000000001,
#    31.0,
#    17.0,
#    124.00000000000004,
#    12.999999999999998,
#    377.00000000000017,
#    75.00000000000001,
#    207.00000000000003,
#    59.00000000000001,
#    9.0],
#   'smiles': ['COc1ncc(Nc2ncc(C(C)(C)O)cc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ncc(Nc2ncc(C(C)(C)N)cc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ncc(Nc2ncc(C(C)(C)O)nc2-c2cc(N)nc(C)n2)cc1F',
#    'COc1ncc(Nc2ncc(C(O)C(F)(F)F)cc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ccc(Nc2ncc(C(C)(O)C(F)(F)F)cc2-c2nc(C)nc(N)n2)cn1',
#    'COc1ncc(Nc2ncc(C(C)(C)O)cc2-c2cc(N)nc(C)n2)cc1F',
#    'COc1ncc(Nc2ncc(C(C)(C)C(=O)O)cc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ncc(Nc2ncc(C(O)C(C)(C)O)cc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ncc(Nc2ncc(C(C)(C)O)cc2-c2nc(C)nc(N)n2)cc1C(F)(F)F',
#    'COc1ncc(Nc2ncc(C(C)O)cc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ncc(Nc2ncc(C(OC(=O)c3cccc(Cl)c3)C(C)(C)O)cc2-c2nc(C)nc(N)n2)cc1F'],
#   'indices': [696, 698, 704, 730, 735, 750, 751, 752, 753, 754, 756],
#   'valid_count': 11,
#   'invalid_count': 0},
#  'smooth_results': {'molecules': [<rdkit.Chem.rdchem.Mol at 0x1eda1591000>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1591070>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda15910e0>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1591150>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda15911c0>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1591230>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda15912a0>,
#    <rdkit.Chem.rdchem.Mol at 0x1eda1591310>],
#   'properties': [22.0,
#    12.999999999999998,
#    33.0,
#    19.0,
#    12.000000000000002,
#    4.0,
#    4.0,
#    17.0],
#   'smiles': ['COc1ncc(Nc2ncc(F)cc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ncc(Nc2ncc(C=O)cc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ncc(Nc2nc(C)ccc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ncc(Nc2ncccc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ccc(Nc2ncc(-c3cncc(F)c3)cc2-c2nc(C)nc(N)n2)cn1',
#    'COc1ncc(Nc2nc(-c3cccnc3)ccc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ncc(Nc2ncc(C(C)(C)O)cc2-c2nc(C)nc(N)n2)cc1F',
#    'COc1ncc(Nc2ncc(C(O)C(F)(F)F)cc2-c2nc(C)nc(N)n2)cc1F'],
#   'indices': [638, 640, 650, 678, 683, 685, 696, 730],
#   'valid_count': 8,
#   'invalid_count': 0},
#  'fingerprint_type': 'MACCS',
#  'threshold': 0.9,
#  'cluster_index': 10}

# %% [markdown]
# ### Below is the space to play around with the code using different datasets and parameters for efficient activity cliff identification. Have fun!! :)
